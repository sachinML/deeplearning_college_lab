# %%
import keras
from keras.datasets import mnist
from keras import utils
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
from PIL import Image
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train_new, y_train_new = x_train[(y_train==0) | (y_train==1)], y_train[(y_train==0) | (y_train==1)]
y_train_new
# Out:
# array([0, 1, 1, ..., 1, 0, 1], dtype=uint8)

# %%
x_train_final = x_train_new.reshape((-1, 784)).T
x_train_final.shape
# Out:
# (784, 12665)

# %%
x_test_new, y_test_new = x_test[(y_test==0) | (y_test==1)], y_test[(y_test==0) | (y_test==1)]
x_test_new.shape
# Out:
# (2115, 28, 28)

# %%
x_test_final = x_test_new.reshape((-1, 784)).T
x_test_final.shape
# Out:
# (784, 2115)

# %%
x_train_final = x_train_final / 255
x_test_final = x_test_final / 255

# %%
# sigmoid
def sigmoid(z):
    s = 1/(1+np.exp(-z))
    return s

# %%
# initialize_with_zeros

def initialize_with_zeros(dim):
    w = np.zeros((dim,1))
    b = 0.0
    assert(w.shape == (dim, 1))  
    assert(isinstance(b, float) or isinstance(b, int))
    
    return w, b

# %%
# propagate

def propagate(w, b, X, Y):
    m = X.shape[1]
    
    # FORWARD PROPAGATION (FROM X TO COST)
   
    A = sigmoid(np.dot(w.T,X)+b)                                   
  #  cost = (-1/m)*np.sum((Y*np.log(A))+((1-Y)*np.log(1-A)))  
    
    logprobs = np.multiply(np.log(A), Y) + np.multiply((1 - Y), np.log(1 - A))
    cost = -np.sum(logprobs) / m
  
    cost = float(np.squeeze(cost))
    assert(isinstance(cost, float))
    # BACKWARD PROPAGATION (TO FIND GRAD)
   
    dw = (1/m)*np.dot(X,(A-Y).T)
    db = (1/m)*np.sum((A-Y))
    

    assert(dw.shape == w.shape)
    assert(db.dtype == float)
   # cost = np.squeeze(cost)
    #assert(cost.shape == ())
    
    grads = {"dw": dw,
             "db": db}
    
    return grads,cost

# %%
# GRADED FUNCTION: update_parameters

def optimize(w,b,X,Y, learning_rate):
    grads, cost = propagate(w,b,X,Y)
    
    
    dw = grads["dw"]
    db = grads["db"]
    ## END CODE HERE ###
    
    # Update rule for each parameter
    ### START CODE HERE ### (≈ 4 lines of code)
    w = w - learning_rate*dw
    b = b - learning_rate*db
    ### END CODE HERE ###
    
   # params = {"w": w,
    #          "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    return w,b, grads, cost

# %%
# GRADED FUNCTION: predict

def predict(w,b, X):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (red: 0 / blue: 1)
    """
    A2 = sigmoid(np.dot(w.T,X)+b)
    # Computes probabilities using forward propagation, and classifies to 0/1 using 0.5 as the threshold.
    ### START CODE HERE ### (≈ 2 lines of code)
 #   A2, cache = forward_propagation(X,parameters)
    predictions = 1*(A2>0.5)
    ### END CODE HERE ###
    
    return predictions

# %%
# GRADED FUNCTION: model

def model(X_train, Y_train, X_test, Y_test, learning_rate,num_iterations=10000,print_cost=False):
    
    
    ### START CODE HERE ###
    
    # initialize parameters with zeros (≈ 1 line of code)
    w, b = initialize_with_zeros(X_train.shape[0])

    # Gradient descent (≈ 1 line of code)
   # params, grads, cost = optimize(w, b, X_train, Y_train, learning_rate)
    
    # Retrieve parameters w and b from dictionary "parameters"
  #  w = params["w"]
   # b = params["b"]
    
    for i in range(0, num_iterations):
      #  Y_prediction_test = predict(w, b, X_test)
       # Y_prediction_train = predict(w, b, X_train)
        
        w,b, grads, costs = optimize(w, b, X_train, Y_train, learning_rate)
        
        d = {"costs": costs, "w" : w, "b" : b, "learning_rate" : learning_rate, "num_iterations": num_iterations}
        
    ### END CODE HERE ###
        
    # Print train/test Errors
       # print("train accuracy: {} %".format(100.0 - np.mean(np.abs(Y_prediction_train-Y_train)*100.0)))
        #print("test accuracy: {} %".format(100.0 - np.mean(np.abs(Y_prediction_test-Y_test)*100.0)))
   # accuracy = float((np.dot(Y,predictions.T) + np.dot(1-Y,1-predictions.T))/float(Y.size)*100)
   # print ("test Accuracy for {} %".format(np.mean(Y_prediction_test)))
    #print ("train Accuracy for {} %".format(np.mean(Y_prediction_train)))

       # if print_cost and i % 1000 == 0:
        #    print ("Cost after iteration %i: %f" %(i, cost))
     #   d = { #"costs": cost,
     #        "Y_prediction_test": Y_prediction_test, 
      #       "Y_prediction_train" : Y_prediction_train, 
       #      "w" : w, 
        #     "b" : b}
             #"learning_rate" : learning_rate}
            
    
    return d

# %%
d = model(x_train_final, y_train_new, x_test_final, y_test_new, 0.005, num_iterations=10000,print_cost=True)

# %%
b
# Out:
# 0.20051619239301452

# %%
w
# Out:
# array([[ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
# ...

# %%
lr
# Out:
# 0.005

# %%
# Print accuracy
predictions = predict(w,b, x_test_final)
print ('Accuracy: %d' % float((np.dot(y_test_new,predictions.T) + np.dot(1-y_test_new,1-predictions.T))/float(y_test_new.size)*100) + '%')
# Out:
# Accuracy: 99%

# %%
cost
# Out:
# 0.009138982607797663

# %%
# Plot learning curve (with costs)
costs = np.squeeze(d['costs'])
i = d["num_iterations"]
plt.scatter(i,costs)
plt.ylabel('cost')
plt.xlabel('iterations (per hundreds)')
plt.title("Learning rate =" + str(d["learning_rate"]))
plt.show()

# %%
learning_rates = [0.05, 0.005, 0.0005]
models = {}
for i in learning_rates:
    print ("learning rate is: " + str(i))
    models[str(i)] = model(x_train_final, y_train_new, x_test_final, y_test_new, i)
    print ('\n' + "-------------------------------------------------------" + '\n')

for i in learning_rates:
    plt.plot(np.squeeze(models[str(i)]["costs"]), label= str(models[str(i)]["learning_rate"]))

plt.ylabel('cost')
plt.xlabel('iterations (hundreds)')

legend = plt.legend(loc='upper center', shadow=True)
frame = legend.get_frame()
frame.set_facecolor('0.90')
plt.show()
# Out:
# learning rate is: 0.05
# train accuracy: 99.02881958152389 %
# test accuracy: 99.57446808510639 %
#
# -------------------------------------------------------
#
# learning rate is: 0.005
# train accuracy: 99.02881958152389 %
# test accuracy: 99.57446808510639 %
#
# -------------------------------------------------------
#
# learning rate is: 0.0005
# train accuracy: 99.02881958152389 %
# test accuracy: 99.57446808510639 %
#
# -------------------------------------------------------

# %%
# Example of a picture that was wrongly classified.
index = 5
plt.imshow(x_test_final[:,index].reshape((28, 28)))
#print ("y = " + str(test_set_y[0,index]) + ", you predicted that it is a \"" + classes[d["Y_prediction_test"][0,index]].decode("utf-8") +  "\" picture.")
