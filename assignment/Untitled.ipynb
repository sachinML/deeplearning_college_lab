# %%
'''Keras MNIST MLP Example 
'''

from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

batch_size = 128
num_classes = 10
epochs = 10

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(num_classes, activation='softmax', input_shape=(784,)))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                7850
# ...
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.5982 - accuracy: 0.8521 - val_loss: 0.3430 - val_accuracy: 0.9072
# Epoch 2/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3302 - accuracy: 0.9083 - val_loss: 0.2985 - val_accuracy: 0.9169
# Epoch 3/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.3011 - accuracy: 0.9162 - val_loss: 0.2865 - val_accuracy: 0.9195
# Epoch 4/10
# 469/469 [==============================] - 1s 2ms/step - loss: 0.2880 - accuracy: 0.9196 - val_loss: 0.2774 - val_accuracy: 0.9223
# Epoch 5/10
# ...

# %%
import matplotlib.pyplot as plt
def Model(x_train, y_train,x_test, y_test, batch_size, epochs, l, r):
    model = Sequential()
    
    model.add(Dense(50, activation='relu', input_shape=(784,)))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(10, activation='softmax'))
   # model.add(Dense(1, activation='softmax'))
  #  model.summary()
    
    # Set up the model algorithm, loss, optimizer 
    model.compile(loss=l, optimizer=r, metrics=['accuracy'])
    
    history = model.fit(x_train, y_train, batch_size, epochs, validation_data=(x_test, y_test))
    
    # perform prediction using the test data
    y_pred = model.predict(x_test);
    
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
    
   # print("Test loss: ", model.evaluate(x_test, y_test))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train','test'], loc = 'lower right')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('model_loss')
    plt.xlabel('epoch')
    plt.legend(['train','test'], loc = 'upper right')
    plt.show()


    
    
    return y_pred

# %%
y_pred_1 = Model(x_train, y_train, x_test, y_test, 128, 50, 'categorical_crossentropy', RMSprop())
# Out:
# Epoch 1/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4713 - accuracy: 0.8662 - val_loss: 0.2340 - val_accuracy: 0.9324
# Epoch 2/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2130 - accuracy: 0.9387 - val_loss: 0.1829 - val_accuracy: 0.9479
# Epoch 3/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1657 - accuracy: 0.9525 - val_loss: 0.1618 - val_accuracy: 0.9513
# Epoch 4/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1388 - accuracy: 0.9597 - val_loss: 0.1402 - val_accuracy: 0.9578
# Epoch 5/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1194 - accuracy: 0.9651 - val_loss: 0.1315 - val_accuracy: 0.9616
# Epoch 6/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1061 - accuracy: 0.9686 - val_loss: 0.1316 - val_accuracy: 0.9611
# Epoch 7/50
# ...

# %%
y_pred_2 = Model(x_train, y_train, x_test, y_test, 110, 50, 'categorical_crossentropy', RMSprop())
# Out:
# Epoch 1/50
# ...
# 546/546 [==============================] - 2s 4ms/step - loss: 0.4258 - accuracy: 0.8816 - val_loss: 0.2311 - val_accuracy: 0.9347
# Epoch 2/50
# 546/546 [==============================] - 2s 3ms/step - loss: 0.2021 - accuracy: 0.9421 - val_loss: 0.1685 - val_accuracy: 0.9515
# Epoch 3/50
# 546/546 [==============================] - 2s 3ms/step - loss: 0.1568 - accuracy: 0.9547 - val_loss: 0.1531 - val_accuracy: 0.9541
# Epoch 4/50
# 546/546 [==============================] - 2s 3ms/step - loss: 0.1302 - accuracy: 0.9619 - val_loss: 0.1331 - val_accuracy: 0.9615
# Epoch 5/50
# 546/546 [==============================] - 2s 3ms/step - loss: 0.1130 - accuracy: 0.9666 - val_loss: 0.1314 - val_accuracy: 0.9611
# Epoch 6/50
# 546/546 [==============================] - 2s 3ms/step - loss: 0.1006 - accuracy: 0.9703 - val_loss: 0.1302 - val_accuracy: 0.9625
# Epoch 7/50
# ...

# %%
from keras.optimizers import SGD
y_pred_3 = Model(x_train, y_train, x_test, y_test, 128, 50, 'categorical_crossentropy', SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Epoch 1/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.5385 - accuracy: 0.8395 - val_loss: 0.2745 - val_accuracy: 0.9196
# Epoch 2/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2494 - accuracy: 0.9278 - val_loss: 0.2187 - val_accuracy: 0.9351
# Epoch 3/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2006 - accuracy: 0.9423 - val_loss: 0.1758 - val_accuracy: 0.9470
# Epoch 4/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1681 - accuracy: 0.9513 - val_loss: 0.1548 - val_accuracy: 0.9526
# Epoch 5/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1466 - accuracy: 0.9573 - val_loss: 0.1393 - val_accuracy: 0.9581
# Epoch 6/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1309 - accuracy: 0.9614 - val_loss: 0.1264 - val_accuracy: 0.9621
# Epoch 7/50
# ...

# %% [markdown]
# 3

# %%
def Modeld(x_train, y_train,x_test, y_test, batch_size, epochs, l, r, p):
    model = Sequential()
    
    model.add(Dense(50, activation='relu', input_shape=(784,)))
    model.add(Dropout(p))
    model.add(Dense(20, activation='relu'))
    model.add(Dropout(p))
    model.add(Dense(10, activation='softmax'))
   # model.add(Dense(1, activation='softmax'))
  #  model.summary()
    
    # Set up the model algorithm, loss, optimizer 
    model.compile(loss=l, optimizer=r, metrics=['accuracy'])
    
    history = model.fit(x_train, y_train, batch_size, epochs, validation_data=(x_test, y_test))
    
    # perform prediction using the test data
    y_pred = model.predict(x_test);
    
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])
    
   # print("Test loss: ", model.evaluate(x_test, y_test))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train','test'], loc = 'lower right')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('model_loss')
    plt.xlabel('epoch')
    plt.legend(['train','test'], loc = 'upper right')
    plt.show()


    
    
    return y_pred

# %%
y_pred_d1 = Modeld(x_train, y_train, x_test, y_test, 128, 50, 'categorical_crossentropy', 
                  SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True), 0.25)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9424 - accuracy: 0.6913 - val_loss: 0.3152 - val_accuracy: 0.9133
# Epoch 2/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4906 - accuracy: 0.8518 - val_loss: 0.2380 - val_accuracy: 0.9307
# Epoch 3/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4117 - accuracy: 0.8770 - val_loss: 0.2043 - val_accuracy: 0.9403
# Epoch 4/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3645 - accuracy: 0.8924 - val_loss: 0.1786 - val_accuracy: 0.9468
# Epoch 5/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3369 - accuracy: 0.9013 - val_loss: 0.1656 - val_accuracy: 0.9490
# Epoch 6/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3075 - accuracy: 0.9107 - val_loss: 0.1520 - val_accuracy: 0.9552
# Epoch 7/50
# ...

# %%
y_pred_d2 = Modeld(x_train, y_train, x_test, y_test, 128, 50, 'categorical_crossentropy', 
                  SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True), 0.15)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.8186 - accuracy: 0.7414 - val_loss: 0.2907 - val_accuracy: 0.9160
# Epoch 2/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4036 - accuracy: 0.8785 - val_loss: 0.2238 - val_accuracy: 0.9323
# Epoch 3/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3257 - accuracy: 0.9029 - val_loss: 0.1889 - val_accuracy: 0.9432
# Epoch 4/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2818 - accuracy: 0.9167 - val_loss: 0.1668 - val_accuracy: 0.9495
# Epoch 5/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2533 - accuracy: 0.9246 - val_loss: 0.1501 - val_accuracy: 0.9553
# Epoch 6/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2348 - accuracy: 0.9303 - val_loss: 0.1399 - val_accuracy: 0.9585
# Epoch 7/50
# ...

# %%
y_pred_d3 = Modeld(x_train, y_train, x_test, y_test, 128, 50, 'categorical_crossentropy', 
                  SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True), 0.10)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.7082 - accuracy: 0.7782 - val_loss: 0.2766 - val_accuracy: 0.9220
# Epoch 2/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3477 - accuracy: 0.8971 - val_loss: 0.2097 - val_accuracy: 0.9386
# Epoch 3/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2825 - accuracy: 0.9165 - val_loss: 0.1792 - val_accuracy: 0.9472
# Epoch 4/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2421 - accuracy: 0.9285 - val_loss: 0.1621 - val_accuracy: 0.9516
# Epoch 5/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2196 - accuracy: 0.9347 - val_loss: 0.1434 - val_accuracy: 0.9568
# Epoch 6/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2009 - accuracy: 0.9401 - val_loss: 0.1350 - val_accuracy: 0.9596
# Epoch 7/50
# ...
